# %% [markdown]
# # Training CNN Models
# **Authors:** Dickson Owuor, Raymond Cao
#
# September 2025
#
# ## Main Goals
# To train a Reinforcement Learning agent to learn to select the best/optimal image filters that generate the best graph for an SEM image.
#    * We use a CNN model to predict if the generated graph is good/bad.
#       * The CNN model is trained on a dataset of SEM images and their corresponding graph images.
#       * The CNN model is used to predict the goodness of the graph image.
#    * We use an MDP to train the agent to select the best image filters.
#       * The MDP is trained on a dataset of SEM images and their corresponding graph images.
#       * The MDP is used to select the best image filters.

# %%
# Installing Libraries (if not installed)
#!pip install torch torchvision

# %%
# Import Libraries
import os
import torch
from PIL import Image
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

from src.train_models import train_cnn_model, plot_performance, cnn_normalize_images, get_image_normalizations, \
    cnn_fc_layer, run_cnn_model
