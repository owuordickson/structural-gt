# %%
from matplotlib.backends.backend_pdf import PdfPages
from src.sgtlib.utils.sgt_utils import sgt_excel_to_dataframe, gen_scaling_plot

# Uncomment to install Libraries (if not installed)
#!pip3 install openpyxl

# %%
# Read the Excel files and save in one DataFrame
allowed_ext = ".xlsx"
excel_dir_path = "analysis/n_200/"
pdf_file = "analysis/n_200/scaling_results-200.pdf"
plt_figs = []

all_sheets = sgt_excel_to_dataframe(excel_dir_path, allowed_ext)
print(all_sheets.keys())
# Out:
# dict_keys(['Nodes-Edges', 'Nodes-Edges(Fit)', 'Nodes-Degree', 'Nodes-Degree(Fit)', 'Nodes-Diameter', 'Nodes-Diameter(Fit)', 'Nodes-Density', 'Nodes-Density(Fit)', 'Nodes-ASC', 'Nodes-ASC(Fit)', 'Nodes-ACC', 'Nodes-ACC(Fit)', 'Nodes-BC', 'Nodes-BC(Fit)', 'Nodes-EC', 'Nodes-EC(Fit)', 'Nodes-CC', 'Nodes-CC(Fit)', 'Nodes-GE', 'Nodes-GE(Fit)'])

# %%
# Filter the relevant materials and parameters
materials = ['BSE 017', 'BSE 011', 'BSE 024', 'BSE 025']
material_names = ['PAN/CGO', 'Carb. PAN', 'PAN', 'Carb. PAN/CGO']
parameters = ['Nodes', 'Edges', 'AD', 'Diameter', 'GD', 'BC', 'CC', 'EC']

material_labels = {key: name for (name, key) in zip(material_names, materials)}

# %%
"""
Graph Density
"""
df_dens = all_sheets['Nodes-Density']
plt_fig = gen_scaling_plot("Graph Density", df_dens, material_labels)
plt_figs.append(plt_fig)
# Out:
# C:\Users\owuor\owProjects\StructuralGT\.venv_sgt\Lib\site-packages\scipy\stats\_resampling.py:960: RuntimeWarning: invalid value encountered in scalar subtract
#   cmps = null_distribution >= observed - gamma

# %%
"""
Betweenness
"""
df_bet = all_sheets['Nodes-BC']
plt_fig = gen_scaling_plot("Betweenness Centrality", df_bet, material_labels)
plt_figs.append(plt_fig)
# Out:
# C:\Users\owuor\owProjects\StructuralGT\.venv_sgt\Lib\site-packages\scipy\stats\_resampling.py:960: RuntimeWarning: invalid value encountered in scalar subtract
#   cmps = null_distribution >= observed - gamma

# %%
"""
Closeness
"""
df_clo = all_sheets['Nodes-CC']
plt_fig = gen_scaling_plot("Closeness Centrality", df_clo, material_labels)
plt_figs.append(plt_fig)
# Out:
# C:\Users\owuor\owProjects\StructuralGT\.venv_sgt\Lib\site-packages\scipy\stats\_resampling.py:960: RuntimeWarning: invalid value encountered in scalar subtract
#   cmps = null_distribution >= observed - gamma

# %%
"""
Eigenvector
"""
df_eig = all_sheets['Nodes-EC']
plt_fig = gen_scaling_plot("Eigenvector Centrality", df_eig, material_labels)
plt_figs.append(plt_fig)
# Out:
# C:\Users\owuor\owProjects\StructuralGT\.venv_sgt\Lib\site-packages\scipy\stats\_resampling.py:960: RuntimeWarning: invalid value encountered in scalar subtract
#   cmps = null_distribution >= observed - gamma

# %%
"""
No. Edges
"""
df_edges = all_sheets['Nodes-Edges']
plt_fig = gen_scaling_plot("Edges", df_edges, material_labels, skip_test=True)
plt_figs.append(plt_fig)

# %%
"""
Average Degree
"""
df_deg = all_sheets['Nodes-Degree']
plt_fig = gen_scaling_plot("Average Degree", df_deg, material_labels, skip_test=True)
plt_figs.append(plt_fig)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 14

# %%
"""
Network Diameter
"""
df_dia = all_sheets['Nodes-Diameter']
plt_fig = gen_scaling_plot("Network Diameter", df_dia, material_labels, skip_test=True)
plt_figs.append(plt_fig)

# %%
"""
Assortativity Coefficient
"""
df_asc = all_sheets['Nodes-ASC']
plt_fig = gen_scaling_plot("Assortativity Coefficient", df_asc, material_labels, skip_test=True)
plt_figs.append(plt_fig)

# %%
"""
Clustering Coefficient
"""
df_acc = all_sheets['Nodes-ACC']
plt_fig = gen_scaling_plot("Clustering Coefficient", df_acc, material_labels, skip_test=True)
plt_figs.append(plt_fig)

# %%
"""
Global Efficiency
"""
df_ge = all_sheets['Nodes-GE']
plt_fig = gen_scaling_plot("Global Efficiency", df_ge, material_labels, skip_test=True)
plt_figs.append(plt_fig)

# %%
with PdfPages(pdf_file) as pdf:
    for fig in plt_figs:
        pdf.savefig(fig)
